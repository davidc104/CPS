# %%
import pandas as pd

path = "./age_employed.csv"
df = pd.read_csv(path)

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>mo_age</th>\n      <th>mo_employed</th>\n      <th>ks_age</th>\n      <th>ks_employed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>16</td>\n      <td>9761</td>\n      <td>15</td>\n      <td>8663</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>17</td>\n      <td>17242</td>\n      <td>16</td>\n      <td>7179</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>18</td>\n      <td>39670</td>\n      <td>17</td>\n      <td>10054</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>19</td>\n      <td>49920</td>\n      <td>18</td>\n      <td>11214</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>20</td>\n      <td>56718</td>\n      <td>19</td>\n      <td>10464</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>21</td>\n      <td>75320</td>\n      <td>20</td>\n      <td>21341</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <
# ...

# %%
path = "./age_unemployed.csv"
df = pd.read_csv(path)

df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>mo_age</th>\n      <th>mo_unemployed</th>\n      <th>ks_age</th>\n      <th>ks_unemployed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>15</td>\n      <td>0.0</td>\n      <td>NaN</td>\n      <td>0.0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>16</td>\n      <td>3492.0</td>\n      <td>16.0</td>\n      <td>3651.0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>17</td>\n      <td>NaN</td>\n      <td>17.0</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>18</td>\n      <td>10612.0</td>\n      <td>18.0</td>\n      <td>7008.0</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>19</td>\n      <td>NaN</td>\n      <td>19.0</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>20</td>\n      <td>4201.0</td>\n      <td>20.0</td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>6</th
# ...

# %%
path = "./education_employed.csv"
df = pd.read_csv(path)

df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>snum</th>\n      <th>state_abbr</th>\n      <th>bachelor_employed</th>\n      <th>master_employed</th>\n      <th>doctor_employed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>AL</td>\n      <td>444832</td>\n      <td>247612</td>\n      <td>40823</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>10</td>\n      <td>DE</td>\n      <td>107975</td>\n      <td>43587</td>\n      <td>18565</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>11</td>\n      <td>DC</td>\n      <td>130167</td>\n      <td>100907</td>\n      <td>21867</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>12</td>\n      <td>FL</td>\n      <td>2624229</td>\n      <td>987350</td>\n      <td>190551</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>13</td>\n      <td>GA</td>\n      <td>1129454</td>\n      <td>515436</td>\n      <td>90617</td>\
# ...

# %%
path = "./education_unemployed.csv"
df = pd.read_csv(path)

df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>snum</th>\n      <th>state_abbr</th>\n      <th>bachelor_unemployed</th>\n      <th>master_unemployed</th>\n      <th>doctor_unemployed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>AL</td>\n      <td>4251</td>\n      <td>0</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>10</td>\n      <td>DE</td>\n      <td>950</td>\n      <td>0</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>11</td>\n      <td>DC</td>\n      <td>2413</td>\n      <td>2239</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>12</td>\n      <td>FL</td>\n      <td>53546</td>\n      <td>14206</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>13</td>\n      <td>GA</td>\n      <td>17780</td>\n      <td>14455</td>\n      <td>0</td>\n    </tr>\n    <tr>\n      <th>5</th>\
# ...
